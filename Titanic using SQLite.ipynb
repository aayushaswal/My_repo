# %%
#importing the library
import sqlite3
import numpy as np
import pandas as pd

# %%
#connecting the jupyter notebook with DB
conn = sqlite3.connect('titanic.db')
cursor = conn.cursor()

# %%
# creating the table column name  in DB

create_table_query= """
CREATE TABLE IF NOT EXISTS titanic(
Passenger_Id integer primary key,
survived INTEGER,
pclass INTEGER,
name TEXT,
sex TEXT,
age REAL,
SibSp INTEGER,
parch INTEGER,
fare REAL,
Embarked TEXT
)
"""

# %%
#execute and commit the table
cursor.execute(create_table_query)
conn.commit()

# %%
#checking the table info
cursor.execute("PRAGMA table_info(titanic)")
print(cursor.fetchall())
# Out:
# [(0, 'Passenger_Id', 'INTEGER', 0, None, 1), (1, 'survived', 'INTEGER', 0, None, 0), (2, 'pclass', 'INTEGER', 0, None, 0), (3, 'name', 'TEXT', 0, None, 0), (4, 'sex', 'TEXT', 0, None, 0), (5, 'age', 'REAL', 0, None, 0), (6, 'SibSp', 'INTEGER', 0, None, 0), (7, 'parch', 'INTEGER', 0, None, 0), (8, 'fare', 'REAL', 0, None, 0), (9, 'Embarked', 'TEXT', 0, None, 0)]

# %%
# read the titanic data
data= pd.read_csv('titanic.csv')
data
# Out:
#       Passenger_Id  Survived  Pclass  \
# 0                1       0.0       3
# 1                2       1.0       1
# 2                3       1.0       3
# 3                4       1.0       1
# 4                5       0.0       3
# ...            ...       ...     ...
# 1304          1305       NaN       3
# 1305          1306       NaN       1
# 1306          1307       NaN       3
# 1307          1308       NaN       3
# 1308          1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# # replacing the nan value as it giving error while inserting the data and there is no concept of null in sqlite so we replace it by -9999

# %%
data.replace(np.nan, -9999, inplace=True)
data
# Out:
#       Passenger_Id  Survived  Pclass  \
# 0                1       0.0       3
# 1                2       1.0       1
# 2                3       1.0       3
# 3                4       1.0       1
# 4                5       0.0       3
# ...            ...       ...     ...
# 1304          1305   -9999.0       3
# 1305          1306   -9999.0       1
# 1306          1307   -9999.0       3
# 1307          1308   -9999.0       3
# 1308          1309   -9999.0       3
#
#                                                    Name     Sex     Age  \
# 0                               Braund, Mr. Owen Harris    male    22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0
# 2                                Heikkinen, Miss. Laina  female    26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0
# 4                              Allen, Mr. William Henry    male    35.0
# ...                                                 ...     ...     ...
# ...

# %% [markdown]
# check the output of database table

# %%
query="SELECT * FROM titanic"
df = pd.read_sql_query(query, conn)
df
# Out:
# Empty DataFrame
# Columns: [Passenger_Id, survived, pclass, name, sex, age, SibSp, parch, fare, Embarked]
# Index: []

# %% [markdown]
# # inserting the data  and commit the changes

# %%
for index, row in data.iterrows():
    insert_data_query = f"""
    INSERT INTO titanic (Passenger_Id, survived, pclass, name, sex, age, SibSp, parch, fare, Embarked) VALUES
    ({row['Passenger_Id']}, {row['Survived']}, {row['Pclass']}, '{row['Name']}', '{row['Sex']}', {row['Age']}, {row['SibSp']}, {row['Parch']}, {row['Fare']},'{row['Embarked']}')
    """
    cursor.execute(insert_data_query)

# %%
#cursor.execute("delete from titanic")

# Commit the changes
conn.commit()

# %%
#checking the complete output 
query="SELECT * FROM titanic"
df = pd.read_sql_query(query, conn)
df
# Out:
#       Passenger_Id  survived  pclass  \
# 0                1         0       3
# 1                2         1       1
# 2                3         1       3
# 3                4         1       1
# 4                5         0       3
# ...            ...       ...     ...
# 1304          1305     -9999       3
# 1305          1306     -9999       1
# 1306          1307     -9999       3
# 1307          1308     -9999       3
# 1308          1309     -9999       3
#
#                                                    name     sex     age  \
# 0                               Braund, Mr. Owen Harris    male    22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0
# 2                                Heikkinen, Miss. Laina  female    26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0
# 4                              Allen, Mr. William Henry    male    35.0
# ...                                                 ...     ...     ...
# ...

# %%
# total no of people embarked from three different location. most of them was from Southampton then Cherbourg then Queenstown and don't have data for two rows
query="SELECT Embarked,count(*) FROM titanic group by Embarked"
df = pd.read_sql_query(query, conn)
df
# Out:
#       Embarked  count(*)
# 0        -9999         2
# 1    Cherbourg       270
# 2   Queenstown       123
# 3  Southampton       914

# %%
# maximum age of person travelling  in the voyage
query="SELECT * FROM titanic order by age desc limit 1"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Passenger_Id  survived  pclass                                  name   sex  \
# 0           631         1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#     age  SibSp  parch  fare     Embarked
# 0  80.0      0      0  30.0  Southampton

# %%
#total people travelling in titanic was 1309 out which 843 are male and 466 are female
query="SELECT sex,count(*) FROM titanic group by sex"
df = pd.read_sql_query(query, conn)
df
# Out:
#       sex  count(*)
# 0  female       466
# 1    male       843

# %%
#out of 466 female, 233 were survived, 81 not survived  and there no data about 152 female survival
#out of 843 male, 109 only survived, 468 not survived  while there no data about 266 male.
query="SELECT sex,survived, count(*) as Is_survived FROM titanic group by sex,survived"
df = pd.read_sql_query(query, conn)
df
# Out:
#       sex  survived  Is_survived
# 0  female     -9999          152
# 1  female         0           81
# 2  female         1          233
# 3    male     -9999          266
# 4    male         0          468
# 5    male         1          109

# %%
# Anna Ward share the highest cost of fare.
query="SELECT  NAME,SEX,AGE,EMBARKED,MAX(fare) as maxium_fair_paid FROM titanic"
df = pd.read_sql_query(query, conn)
df
# Out:
#                name     sex   age   Embarked  maxium_fair_paid
# 0  Ward, Miss. Anna  female  35.0  Cherbourg          512.3292

# %%
# maximum number people travelling in the trip having the age between 20 to 60 years
query="SELECT COUNT(*) AS NO_OF_PEOPLE, round(AGE/10,0)*10 AS AGE_GROUP FROM titanic GROUP BY AGE_GROUP ORDER BY AGE_GROUP DESC"
df = pd.read_sql_query(query, conn)
df
# Out:
#    NO_OF_PEOPLE  AGE_GROUP
# 0             2       80.0
# 1            11       70.0
# 2            54       60.0
# 3           109       50.0
# 4           169       40.0
# 5           292       30.0
# 6           300       20.0
# 7            58       10.0
# 8            51        0.0
# 9           263   -10000.0

# %%
#details of all traveller between age of 20 and 60 
query="SELECT * FROM titanic where age between 20 and 60"
df = pd.read_sql_query(query, conn)
df
# Out:
#      Passenger_Id  survived  pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ..            ...       ...     ...
# 783          1299     -9999       1
# 784          1303     -9999       1
# 785          1304     -9999       3
# 786          1306     -9999       1
# 787          1307     -9999       3
#
#                                                   name     sex   age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
query="SELECT min(age) as min_age,max(age) as max_age, avg(age) as avg_age, count(*) as total_count,Embarked FROM titanic group by Embarked"
df = pd.read_sql_query(query, conn)
df
# Out:
#    min_age  max_age      avg_age  total_count     Embarked
# 0     38.0     62.0    50.000000            2        -9999
# 1  -9999.0     71.0 -2122.546593          270    Cherbourg
# 2  -9999.0     70.5 -5922.727642          123   Queenstown
# 3  -9999.0     80.0 -1419.035284          914  Southampton

# %%
#showing no of traveller as per passenger class
query="SELECT pclass,count(*) as people FROM titanic group by pclass"
df = pd.read_sql_query(query, conn)
df
# Out:
#    pclass  people
# 0       1     323
# 1       2     277
# 2       3     709

# %%
#maximum no of people survive from passenger class 1 
query="SELECT pclass, survived,count(*) as people_survived FROM titanic group by survived,pclass"
df = pd.read_sql_query(query, conn)
df
# Out:
#    pclass  survived  people_survived
# 0       1     -9999              107
# 1       2     -9999               93
# 2       3     -9999              218
# 3       1         0               80
# 4       2         0               97
# 5       3         0              372
# 6       1         1              136
# 7       2         1               87
# 8       3         1              119

# %%
# total fare paid category wise, for class 3 showing nr=egative due to nan values replace by -9999
query="Select pclass,sum(FARE) as total_amount_paid_class FROM titanic group by pclass"
df = pd.read_sql_query(query, conn)
df
# Out:
#    pclass  total_amount_paid_class
# 0       1               28265.4043
# 1       2                5866.6374
# 2       3                -580.5548

# %%
#list of people who paid fare more than 50
query="Select *  FROM titanic where fare>50"
df = pd.read_sql_query(query, conn)
df
# Out:
#      Passenger_Id  survived  pclass  \
# 0               2         1       1
# 1               4         1       1
# 2               7         0       1
# 3              28         0       1
# 4              32         1       1
# ..            ...       ...     ...
# 235          1292     -9999       1
# 236          1294     -9999       1
# 237          1299     -9999       1
# 238          1303     -9999       1
# 239          1306     -9999       1
#
#                                                   name     sex     age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0      1
# 2                              McCarthy, Mr. Timothy J    male    54.0      0
# 3                       Fortune, Mr. Charles Alexander    male    19.0      3
# 4       Spencer, Mrs. William Augustus (Marie Eugenie)  female -9999.0      1
# ...

# %%
#count of female and male pay fare more than 50 
query="Select sex,count(sex)  FROM titanic where fare >50.0 group by sex"
df = pd.read_sql_query(query, conn)
df
# Out:
#       sex  count(sex)
# 0  female         130
# 1    male         110

# %%
#count of male and female travelling and there age greater than 20
query="Select sex,count(sex)  FROM titanic where age >20 group by sex"
df = pd.read_sql_query(query, conn)
df
# Out:
#       sex  count(sex)
# 0  female         279
# 1    male         519
